# %% [markdown]
# # House prising regression

# %% [markdown]
# # Importing Python Libraries

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Lasso, Ridge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import matplotlib.gridspec as gridspec
import missingno as msno
import scipy.stats as stats 
from scipy.special import boxcox1p
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading dataframes

# %%
house_train_data= pd.read_csv('../project_2/house_price_prediction/train.csv')

# %% [markdown]
# # Exploring data analysis of train dataframe

# %%
#First five records of data

house_train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#Last five records of data

house_train_data.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#Coloumns in data

house_train_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
#Length of data

print('length of house_train_data is:    ', len(house_train_data))
# Out:
# length of house_train_data is:     1460

# %%
#Shape of data

house_train_data.shape
# Out:
# (1460, 81)

# %%
#Dataframe information

house_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#Data types of all coloumns

house_train_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
#Checking missing Values

house_train_data[house_train_data.isnull().any(axis=1)].head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#Count of missing values

np.sum(house_train_data.isnull().any(axis=1))
# Out:
# 1460

# %%
#Is there any missing values?

house_train_data.isnull().values.any()
# Out:
# True

# %%
#Counts of missing values in each column

house_train_data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# #

# %% [markdown]
# # Exploring data analysis of train dataframe

# %%
house_test_data= pd.read_csv('../project_2/house_price_prediction/test.csv')

# %%
#First five records of data

house_test_data.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#Last five records of data

house_test_data.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 1454         Lvl    AllPub  ...           0        0    NaN    NaN
# 1455         Lvl    AllPub  ...           0        0    NaN    NaN
# 1456         Lvl    AllPub  ...           0        0    NaN    NaN
# 1457         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 1458         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#Coloumns in data

house_test_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# Length: 80, dtype: object

# %%
#Length of data

print('length of house_train_data is:    ', len(house_test_data))
# Out:
# length of house_train_data is:     1459

# %%
#Shape of data

house_test_data.shape
# Out:
# (1459, 80)

# %%
#Dataframe information

house_test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
#Data types of all coloumns

house_test_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# Length: 80, dtype: object

# %%
#Checking missing Values

house_test_data[house_test_data.isnull().any(axis=1)].head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#Count of missing values

np.sum(house_test_data.isnull().any(axis=1))
# Out:
# 1459

# %%
#Is there any missing values?

house_test_data.isnull().values.any()
# Out:
# True

# %%
#Counts of missing values in each column

house_test_data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 80, dtype: int64

# %% [markdown]
# # Checking missing values in columns of dataframes

# %%
# Looking at the train data missing values
NANColumns=[]
i=-1
for a in house_train_data.isnull().sum():
    i+=1
    if a!=0:
        print(house_train_data.columns[i],a)
        NANColumns.append(house_train_data.columns[i])
# Out:
# LotFrontage 259
# Alley 1369
# MasVnrType 8
# MasVnrArea 8
# BsmtQual 37
# BsmtCond 37
# BsmtExposure 38
# BsmtFinType1 37
# BsmtFinType2 38
# Electrical 1
# FireplaceQu 690
# GarageType 81
# GarageYrBlt 81
# GarageFinish 81
# GarageQual 81
# GarageCond 81
# PoolQC 1453
# Fence 1179
# MiscFeature 1406

# %%
# Looking at the test data missing values
NANColumns=[]
i=-1
for a in house_test_data.isnull().sum():
    i+=1
    if a!=0:
        print(house_test_data.columns[i],a)
        NANColumns.append(house_train_data.columns[i])
# Out:
# MSZoning 4
# LotFrontage 227
# Alley 1352
# Utilities 2
# Exterior1st 1
# Exterior2nd 1
# MasVnrType 16
# MasVnrArea 15
# BsmtQual 44
# BsmtCond 45
# BsmtExposure 44
# BsmtFinType1 42
# BsmtFinSF1 1
# BsmtFinType2 42
# BsmtFinSF2 1
# BsmtUnfSF 1
# TotalBsmtSF 1
# BsmtFullBath 2
# BsmtHalfBath 2
# KitchenQual 1
# Functional 2
# FireplaceQu 730
# GarageType 76
# GarageYrBlt 78
# GarageFinish 78
# GarageCars 1
# GarageArea 1
# GarageQual 78
# GarageCond 78
# PoolQC 1456
# Fence 1169
# MiscFeature 1408
# SaleType 1

# %% [markdown]
#  #

# %% [markdown]
# # Plotting Hitogram of all columns to check how the values are distributed

# %%
#Hitogram of all columns with their counts

house_train_data.hist(figsize=(80,80),bins = 20)
plt.title("Features Distribution with values counts")
plt.show()

# %% [markdown]
# # plotting columns which represent YEAR

# %%
temporal_features = [feat for feat in house_train_data if "Year" in feat or "Yr" in feat]
print(temporal_features)
for feature in temporal_features:
    sns.scatterplot(x=feature,y="SalePrice",data=house_train_data)
    plt.title(feature)
    plt.show()
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
#sns.scatterplot(x='GarageYrBlt',y="SalePrice",data=house_train_data)
#plt.title('GarageYrBlt vs SalePrice')
#plt.show()

# %%
#sns.scatterplot(x='YrSold',y="SalePrice",data=house_train_data)
#plt.title('YrSold vs SalePrice')
#plt.show()

# %%
#sns.scatterplot(x='YearBuilt',y="SalePrice",data=house_train_data)
#plt.title('YearBuilt vs SalePrice')
#plt.show()

# %%
#sns.scatterplot(x='YearRemodAdd',y="SalePrice",data=house_train_data)
#plt.title('YearRemodAdd vs SalePrice')
#plt.show()

# %% [markdown]
# #

# %%
categorical_features = [feature for feature in house_train_data if house_train_data[feature].nunique() < 22 and feature not in temporal_features]
continuous_features = [feature for feature in house_train_data if feature not in categorical_features and feature not in temporal_features]

print("Discrete_Features:\n",categorical_features)
print("Continuous_Features:\n",continuous_features)
# Out:
# Discrete_Features:
#  ['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageCars', 'GarageQual', 'GarageCond', 'PavedDrive', '3SsnPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'SaleType', 'SaleCondition']
# Continuous_Features:
# ...

# %% [markdown]
# #

# %%
#Scatter plot of each categorical_Features against Sale price on discrete features
def scatterplot(house_train_data,feature,target_feature):
    plt.figure()
    sns.scatterplot(house_train_data[feature],house_train_data[target_feature])
    plt.title(feature)
    plt.show()
for feat in categorical_features:
    scatterplot(house_train_data,feat,"SalePrice")

# %% [markdown]
# # From the insights at the figures, we will use the following *categorical_features:*
#
# # OverallQual, OverallCond, FullBath, TotRmsAbvGrd and GarageCars,  have stong correlation with SalePrice

# %%
#Scatter plot of each Continuous_Features against Sale price on discrete features
def scatterplot(train_data,feature,target_feature):
    plt.figure()
    sns.scatterplot(train_data[feature],train_data[target_feature])
    plt.title(feature)
    plt.show()

    
for feat in continuous_features:
    scatterplot(house_train_data,feat,"SalePrice")

# %% [markdown]
# # From the insights at the figures, we will use the following continuous_features:
#
# # YearBuit, TotalBsmtSF, 1stFlrSF, GrLivArea and GarageArea have stong correlation with SalePrice

# %% [markdown]
# #

# %% [markdown]
# # Looking at the top most correlated features with SalePrice

# %%
#Looking at the most correlated features with SalePrice

corr = house_train_data.corr().nlargest(10,"SalePrice")["SalePrice"].index
cmap = np.corrcoef(house_train_data[corr].values.T)
mask = np.zeros_like(cmap,dtype=bool)
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(20,10))
sns.heatmap(cmap,
            annot=True,
            fmt=".3f",
            annot_kws = {"size":10},
            cmap=sns.cubehelix_palette(),
            xticklabels = corr.values,
            yticklabels = corr.values,
            mask=mask)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #                                     Data Processing

# %%
# Extract the SalePrice

y = house_train_data["SalePrice"]

# %%
# Combining the train and test dataframes

data_concat = pd.concat([house_train_data,house_test_data],axis=0).reset_index(drop=True)

# %%
# Droping the SalePrice and Id columns

data_concat = data_concat.drop(['SalePrice','Id'],axis=1)

# %%
#Function to check missing values

def missing_value(df):
    number = df.isnull().sum().sort_values(ascending=False)
    number = number[number > 0]
    percentage = df.isnull().sum() *100 / df.shape[0]
    percentage = percentage[percentage > 0].sort_values(ascending=False)
    return  pd.concat([number,percentage],keys=["Total","Percentage"],axis=1)
missing_value(data_concat)
# Out:
#               Total  Percentage
# PoolQC         2909   99.657417
# MiscFeature    2814   96.402878
# Alley          2721   93.216855
# Fence          2348   80.438506
# FireplaceQu    1420   48.646797
# LotFrontage     486   16.649538
# GarageCond      159    5.447071
# GarageQual      159    5.447071
# GarageYrBlt     159    5.447071
# GarageFinish    159    5.447071
# GarageType      157    5.378554
# BsmtCond         82    2.809181
# BsmtExposure     82    2.809181
# BsmtQual         81    2.774923
# BsmtFinType2     80    2.740665
# BsmtFinType1     79    2.706406
# MasVnrType       24    0.822199
# MasVnrArea       23    0.787941
# MSZoning          4    0.137033
# BsmtHalfBath      2    0.068517
# Utilities         2    0.068517
# Functional        2    0.068517
# BsmtFullBath      2    0.068517
# BsmtFinSF2        1    0.034258
# BsmtFinSF1        1    0.034258
# Exterior2nd       1    0.034258
# BsmtUnfSF         1    0.034258
# TotalBsmtSF       1    0.034258
# ...

# %%
missing_col = ["Alley", "PoolQC", "MiscFeature","Fence",
               "FireplaceQu","GarageType","GarageFinish",
               "GarageQual","GarageCond",'BsmtQual','BsmtCond',
               'BsmtExposure','BsmtFinType1','BsmtFinType2',
               'MasVnrType']

for col in missing_col:
    data_concat[col] = data_concat[col].fillna("None")

# %%
#LotFrontage, Houses in the same neighborhood would have similar lotfrontage area. 
## filling the numerical features with median and mdeidan is the best suited method for numerical based features
data_concat["LotFrontage"] = data_concat.groupby("Neighborhood")["LotFrontage"].transform(lambda x:x.fillna(x.median()))

# %%
#MasVnrArea, Same apply to the MasVnrArea
## filling the numerical features with median and mdeidan is the best suited method for numerical based features
data_concat["MasVnrArea"] = data_concat.groupby("Neighborhood")["MasVnrArea"].transform(lambda x:x.fillna(x.median()))

# %%
## MSSubClass
## Imputing the missing values with the Mode because mode fill the values with the most accuring values and best for the categorical features
data_concat["MSZoning"] = data_concat.groupby("MSSubClass")["MSZoning"].transform(lambda x: x.fillna(x.mode()[0]))

# %%
## GarageYrBlt
data_concat.loc[data_concat["GarageFinish"] == "None" , "GarageYrBlt"] = data_concat["YearBuilt"]

# %%
## Check on the missing value
missing_value(data_concat)
# Out:
#               Total  Percentage
# Functional        2    0.068517
# Utilities         2    0.068517
# BsmtFullBath      2    0.068517
# BsmtHalfBath      2    0.068517
# GarageArea        1    0.034258
# BsmtFinSF2        1    0.034258
# BsmtUnfSF         1    0.034258
# TotalBsmtSF       1    0.034258
# KitchenQual       1    0.034258
# SaleType          1    0.034258
# BsmtFinSF1        1    0.034258
# Electrical        1    0.034258
# Exterior1st       1    0.034258
# Exterior2nd       1    0.034258
# GarageCars        1    0.034258

# %%
### for the rest of the missing value
## categorical feature are replaced with the mode value
## continuous features are replaced with the median value
missing_feat = missing_value(data_concat).index

# %%
## getting categorical feature

missing_cat = [feat for feat in missing_feat if data_concat[feat].dtype == np.object]

# %%
## filling the categorical features with mode and mode is the best suited method for categorical based features
for feat in missing_cat:
    data_concat[feat] = data_concat[feat].transform(lambda x: x.fillna(x.mode()[0]))

## numerical feature
missing_num = [feat for feat in missing_feat if feat not in missing_cat]

# %%
## filling the numerical features with median and mdeidan is the best suited method for numerical based features
for feat in missing_num:
    data_concat[feat] = data_concat[feat].transform(lambda x: x.fillna(x.median()))  
### Check on the missing value
missing_value(data_concat)
# Out:
# Empty DataFrame
# Columns: [Total, Percentage]
# Index: []

# %%
### Months and years should be consider as categorical features

data_concat["MoSold"] = data_concat["MoSold"].astype(str)
data_concat["YrSold"] = data_concat["YrSold"].astype(str)
data_concat["YearBuilt"] = data_concat["YearBuilt"].astype(str)

# %% [markdown]
# # Normalizing the of Dependant Variable SalePrice

# %%
## Visualization
fig = plt.figure(constrained_layout=True, figsize=(12,8))
grid = gridspec.GridSpec(ncols=3, nrows=4, figure=fig)
 # Histrogram
ax1 = fig.add_subplot(grid[0,:])
sns.distplot(y,ax=ax1)
ax1.set_title("Histrogram of SalePrice")
# QQplot
ax2 = fig.add_subplot(grid[2:,:2])
stats.probplot(y,plot=ax2)
ax2.set_title("QQplot of SalePrice")
 # Boxplot
ax3 = fig.add_subplot(grid[2:,2])
sns.boxplot(y,ax=ax3,orient="v")
ax3.set_title("Boxplot of SalePrice")
plt.show()

# %% [markdown]
# # my insights:
#
# * The SalePrice is right skewed, which indicates that most people are able to afford lower priced house.
# * Easily can notice outliers in SalePrice

# %%
##Check on the kurtosis & the skewness of SalePrice
print("Kurtosis: {}".format(y.kurt()))
print("Skewness: {}".format(y.skew()))
# Out:
# Kurtosis: 6.536281860064529
# Skewness: 1.8828757597682129

# %% [markdown]
# # As indicated in the three charts above, SalePrice is postively-skewed.
#
# Skewness: Defined as the degree of distortion from the symmetrical bell curve or the normal curve.
# Kurtosis: Defined as the measuer of the extreme values (also known as outliers) present in the distribution.

# %%
## Normalize the Dependant Variable(SalePrice)
y = np.log1p(y)

## Visualize of SalePrice after the normalization
fig,(ax1,ax2, ax3) = plt.subplots(3,1,constrained_layout=True,figsize=(12,9))

 # Histrogram
sns.distplot(y,ax=ax1)
ax1.set_title("Histrogram of SalePrice")

# QQplot
stats.probplot(y,plot=ax2)
ax2.set_title("QQplot of SalePrice")

 # Boxplot
sns.boxplot(y,ax=ax3,orient="v")
ax3.set_title("Boxplot of SalePrice")

plt.show()

# %% [markdown]
# # Its better now
# Now let's check on the kurtosis and skewness value of SalePrice

# %%
## Kurtosis and skewness of SalePrice
print("Kurtosis: {}".format(y.kurt()))
print("Skewness: {}".format(y.skew()))
# Out:
# Kurtosis: 0.809519155707878
# Skewness: 0.12134661989685329

# %% [markdown]
# # Now the data are normalised :)

# %%
## Check on the skewness and the kurtosis on continuos data only
continuous_feats = [feat for feat in data_concat.columns if data_concat[feat].dtype != np.object]
skewness = data_concat[continuous_feats].skew().sort_values(ascending=False)
kurtosis = data_concat[continuous_feats].kurt().sort_values(ascending=False)

data_concat_norm = pd.concat([skewness,kurtosis],axis=1,keys=["Skewness","Kurtosis"])

data_concat_norm
# Out:
#                 Skewness    Kurtosis
# MiscVal        21.958480  564.074582
# PoolArea       16.907017  298.633144
# LotArea        12.829025  264.952310
# LowQualFinSF   12.094977  174.932812
# 3SsnPorch      11.381914  149.409834
# KitchenAbvGr    4.304467   19.777937
# BsmtFinSF2      4.148275   18.844397
# EnclosedPorch   4.005950   28.377909
# ScreenPorch     3.948723   17.776704
# BsmtHalfBath    3.933616   14.861472
# MasVnrArea      2.611228    9.319482
# OpenPorchSF     2.536417   10.937353
# WoodDeckSF      1.843380    6.741550
# LotFrontage     1.506478   12.940595
# 1stFlrSF        1.470360    6.956479
# BsmtFinSF1      1.426111    6.908362
# MSSubClass      1.376165    1.457827
# GrLivArea       1.270010    4.121604
# TotalBsmtSF     1.163214    9.155318
# BsmtUnfSF       0.920176    0.404947
# 2ndFlrSF        0.862118   -0.422261
# TotRmsAbvGrd    0.758757    1.169064
# Fireplaces      0.733872    0.076424
# HalfBath        0.694924   -1.033446
# ...

# %%
### Feature with skewness greater than 1 or lower than -1 are considered highly skewed
high_skew = skewness[abs(skewness) > 1].sort_values(ascending=False)

## Visualization of TotalBsmtSF
plt.figure(figsize=(8,6))
sns.distplot(data_concat["TotalBsmtSF"])
plt.show()

# %%
## Look at its kurtosis and skewness value
print("Kurtosis: {}".format(data_concat["TotalBsmtSF"].kurt()))
print("Skewness: {}".format(data_concat["TotalBsmtSF"].skew()))
# Out:
# Kurtosis: 9.155317679440493
# Skewness: 1.1632139475611367

# %%
## import packages
from scipy.special import boxcox1p
from scipy.stats import boxcox_normmax


## Normalization of independant variables
for feat in high_skew.index:
    data_concat[feat] = boxcox1p(data_concat[feat], boxcox_normmax(data_concat[feat] + 1))
## Visualization of TotalBsmtSF after normalization
plt.figure(figsize=(8,6))
sns.distplot(data_concat["TotalBsmtSF"])
plt.show()

# %%
## Look at its kurtosis and skewness value after the normalization
print("Kurtosis: {}".format(data_concat["TotalBsmtSF"].kurt()))
print("Skewness: {}".format(data_concat["TotalBsmtSF"].skew()))
# Out:
# Kurtosis: 4.705259987952178
# Skewness: 0.37016513278332736

# %% [markdown]
# # Now the data is normalized well !!

# %% [markdown]
#  #

# %% [markdown]
# # Adding the new features from the existing featrures because to make the model more distinguish for price predictions !!

# %%
## TotalHouseSF: The total Square Foot of the house
data_concat["TotalHouseSF"] = data_concat["TotalBsmtSF"] + data_concat["1stFlrSF"] + data_concat["2ndFlrSF"]

# %%
## TotalBath: The total number of bathrooms in the house
## TotalBath: The total number of bathrooms in the house
data_concat["TotalBath"] = data_concat["BsmtFullBath"] + data_concat["BsmtFullBath"]*0.5 + data_concat["FullBath"] + data_concat["HalfBath"]*0.5

# %%
## TotalPorchSF: The total square foot of porch area of the house
data_concat["TotalPorchSF"] = data_concat["WoodDeckSF"] + data_concat["OpenPorchSF"] + data_concat["EnclosedPorch"] +data_concat["3SsnPorch"] + data_concat["ScreenPorch"]

# %%
## HouseRemodAge: Number of years the house being remodded to the time it was sold
data_concat["HouseRemodAge"] = data_concat["YrSold"].astype(int) - data_concat["YearRemodAdd"]
data_concat.loc[data_concat["HouseRemodAge"] < 0, "HouseRemodAge"] = 0

# %%
## function 
presence = lambda x: 1 if x > 0 else 0

# %%
## HasPool: Presence of pool
data_concat["HasPool"] = data_concat["PoolArea"].transform(presence)

# %%
## Has2ndFlr: Presence of second floor
data_concat["Has2ndFlr"] = data_concat["2ndFlrSF"].transform(presence)

# %%
## HasGarage: Presence of garage
data_concat["HasGarage"] = data_concat["GarageArea"].transform(presence)

# %%
## HasBsmt: Presence of basement
data_concat["HasBsmt"] = data_concat["TotalBsmtSF"].transform(presence)

# %%
## HasFirePlace: Presence of fireplace
data_concat["HasFirePlace"] = data_concat["Fireplaces"].transform(presence)

# %% [markdown]
# #

# %% [markdown]
# # Deleting the Biased Features

# %%
## Bias feature reducer
bias_feat = []
for feat in data_concat.columns:
    counts = data_concat[feat].value_counts().iloc[0] ## mode value counts
    if counts / len(data_concat) * 100 > 99.94:
        bias_feat.append(feat)

bias_feat
# Out:
# ['Utilities']

# %%
## Remove the bias feature from the dataset
data_concat = data_concat.drop(bias_feat,axis=1)

# %% [markdown]
#  #

# %% [markdown]
# # Coverting the categorical features into continous form by applying the get_dummies function

# %%
data_concat = pd.get_dummies(data_concat).reset_index(drop=True)

# %%
n = len(y)
house_train_data = data_concat[:n]
house_test_data = data_concat[n:]

# %% [markdown]
# #

# %% [markdown]
# # Splitting the Train data into 80% for training and 20% for testing

# %%
X_train, X_test, y_train, y_test =  train_test_split(house_train_data,y,test_size=0.33,random_state=42)
print("Shapes of data: ", X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# Shapes of data:  (978, 441) (482, 441) (978,) (482,)

# %% [markdown]
# # Building the models for training and testing

# %%
## Create an empty list
pipeline_models = []

# Assign all models into the list
seed = 42
models = [Ridge(tol=10,random_state=seed),
          Lasso(tol=1,random_state=seed),
          RandomForestRegressor(random_state=seed),
          ExtraTreesRegressor(random_state=seed),
          GradientBoostingRegressor(),
          DecisionTreeRegressor(),
          KNeighborsRegressor()]

model_names = ["Ridge","Lasso","RFR","ETR","GBoost_Reg","DT_Reg","KNN_Reg"]

## Assign each model to a pipeline
for name, model in zip(model_names,models):
    pipeline = ("Scaled_"+ name,
                Pipeline([("Scaler",StandardScaler()),
                          (name,model)
                         ]))
    pipeline_models.append(pipeline)

# %%
## Create a dataframe to store all the models' cross validation score
evaluate = pd.DataFrame(columns=["model","cv","std"])


## Encoded dataset
for name,model in pipeline_models:
    kfold = KFold(n_splits=7,shuffle=True,random_state=42)
    cv = cross_val_score(model, X_train, y_train, cv=kfold, n_jobs=-1, scoring="r2")
    
    row = evaluate.shape[0]
    evaluate.loc[row,"model"] = name
    evaluate.loc[row,"cv"] = round(cv.mean(),3)
    evaluate.loc[row,"std"] = "+/- {}".format(round(cv.std(),4))
    
    evaluate = evaluate.sort_values("cv",ascending=False)

# %%
## Visualization
fig, ax = plt.subplots(1,1,sharey=False,figsize=(16,9))

## Encoded dataset
bar = sns.barplot(evaluate["model"], evaluate["cv"],ax=ax,palette = sns.cubehelix_palette(evaluate.shape[0]))
for rec in bar.patches:
    height = rec.get_height()
    ax.text(rec.get_x() + rec.get_width()/2, height*1.02,height,ha="center")
ax.set_title("Cross Validate Score")
ax.set_xticklabels(evaluate["model"].to_list(),rotation =50)
# Out:
# [Text(0, 0, 'Scaled_GBoost_Reg'),
#  Text(1, 0, 'Scaled_RFR'),
#  Text(2, 0, 'Scaled_ETR'),
#  Text(3, 0, 'Scaled_Ridge'),
#  Text(4, 0, 'Scaled_KNN_Reg'),
#  Text(5, 0, 'Scaled_DT_Reg'),
#  Text(6, 0, 'Scaled_Lasso')]

# %% [markdown]
# # Best Model is Gradient Boosting Regressor

# %%
final_model = GradientBoostingRegressor()
final_model = final_model.fit(X_train,y_train)
